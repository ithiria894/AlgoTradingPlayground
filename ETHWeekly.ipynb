# %%
import ccxt
import pandas as pd
from IPython.display import display, HTML

# Function to fetch ETH/USDT historical data from Binance
def fetch_data(symbol, timeframe='1w', since='2000-01-01T00:00:00Z'):
    exchange = ccxt.binance()
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=exchange.parse8601(since))

    # Convert to DataFrame
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    # Extract year, month, and week for pivot table analysis
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['week_of_year'] = df.index.isocalendar().week  # Get the week number of the year
    df['week_of_month'] = (df.index.day - 1) // 7 + 1  # Calculate which week of the month
    df['month_week'] = 'M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)

    # Generate a unique "week number" for sorting (unique within the same year)
    df['month_letter'] = df['month'].apply(lambda x: chr(64 + x))  # Convert month to letter (1 -> A, 2 -> B, ..., 12 -> L)
    df['unique_week_number'] = df['month_letter'] + '-M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)
    
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to create the pivot table with positive percentages in green
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('unique_week_number')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='year', columns='unique_week_number', aggfunc='mean')

    # Calculate mean, median, max, and min for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)

    # Add the average, median as the last rows
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value

    return pivot_table

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    ETH_data = fetch_data(symbol)

    # Calculate weekly return
    ETH_data = calculate_weekly_return(ETH_data)

    # Step 1: Filter 2024 Data
    ETH_2024 = ETH_data[ETH_data['year'] == 2024]
    # filter 2024 data and get only 1月-5月还有11月-12月
    ETH_2024 = ETH_2024[(ETH_2024['month'] >= 1) & (ETH_2024['month'] <= 4) | (ETH_2024['month'] >= 11) & (ETH_2024['month'] <= 12)]

    # Step 2: Analyze Historical Data (before 2024) for Buy Signals
    historical_data = ETH_data[ETH_data['year'] < 2024]

    # Create pivot table for historical data
    historical_pivot = create_pivot_table(historical_data, 'weekly_return')
    print("Historical Pivot Table:")
    display(historical_pivot)

    # Extract Avg and Median for each column (historical)
    historical_pivot_avg = historical_pivot.loc['Avg']
    historical_pivot_median = historical_pivot.loc['Median']

    print("\nHistorical Avg:")
    display(historical_pivot_avg)
    print("\nHistorical Median:")
    display(historical_pivot_median)


    # Step 3: Identify Buy Signals (when Avg and Median are both positive)
    buy_signals = historical_pivot_avg[(historical_pivot_avg > 0) & (historical_pivot_median > 0)].index

    # Step 4: Calculate Win Rate for Buy Signals
    # Filter 2024 data where the week belongs to buy signals and check if the return is positive
    ETH_2024['win'] = ETH_2024['unique_week_number'].apply(
        lambda x: 1 if x in buy_signals and ETH_2024.loc[ETH_2024['unique_week_number'] == x, 'weekly_return'].values[0] > 0 else 0
    )

    # Step 5: Calculate total buy signal weeks and winning weeks
    total_buy_signal_weeks = len(ETH_2024[ETH_2024['unique_week_number'].isin(buy_signals)])
    winning_weeks = ETH_2024[ETH_2024['win'] == 1].shape[0]
    total_profit_of_winning_weeks = ETH_2024[ETH_2024['win'] == 1]['weekly_return'].sum()
    # total_loss_of_losing_weeks = win=0 and have buy signal
    total_loss_of_losing_weeks = ETH_2024[(ETH_2024['win'] == 0) & (ETH_2024['unique_week_number'].isin(buy_signals))]['weekly_return'].sum()

    # Step 6: Calculate Win Rate
    if total_buy_signal_weeks > 0:
        win_rate = (winning_weeks / total_buy_signal_weeks) * 100
    else:
        win_rate = 0.0

    # Merge the historical pivot data (Avg and Median) with the 2024 data
    # Add Avg and Median values to the 2024 DataFrame by aligning on unique_week_number
    ETH_2024['Avg'] = ETH_2024['unique_week_number'].map(historical_pivot_avg.to_dict())
    ETH_2024['Median'] = ETH_2024['unique_week_number'].map(historical_pivot_median.to_dict())


    # Display the results with Avg and Median included
    # display(ETH_2024)

    # Output the numbers for total buy signal weeks and winning weeks
    print(f"Total buy signal weeks: {total_buy_signal_weeks}")
    print(f"Total winning weeks: {winning_weeks}")
    print(f"Win rate for buy signals from previous years: {win_rate:.2f}%")
    print(f"Total profit of winning weeks: {total_profit_of_winning_weeks:.2f}%")
    print(f"Total loss of losing weeks: {total_loss_of_losing_weeks:.2f}%")

# Run the main function
main()
# Out:
# Historical Pivot Table:
# unique_week_number    A-M1-W1    A-M1-W2    A-M1-W3    A-M1-W4    A-M1-W5  \
# year
# 2017                      NaN        NaN        NaN        NaN        NaN
# 2018                53.216191  19.936960 -22.180432  19.347950 -34.218346
# 2019               -25.817142   2.890427  -4.686968  -4.177080        NaN
# 2020                 8.251459  13.803221   0.641525  12.226788        NaN
# 2021                28.203163  -1.737307  12.982556  -5.720484        NaN
# 2022               -17.662502   6.183752 -24.138230   2.468688  17.424193
# 2023                 7.483775  20.336395   4.825703   1.062411  -0.955172
# Avg                  8.945824  10.235574  -5.425974   4.201379  -5.916442
# Median               7.867617   9.993486  -2.022722   1.765550  -0.955172
#
# unique_week_number    B-M2-W1    B-M2-W2   B-M2-W3    B-M2-W4    C-M3-W1  ...  \
# year                                                                      ...
# 2017                      NaN        NaN       NaN        NaN        NaN  ...
# 2018                -1.534810  12.666650 -7.663008   2.994795 -16.819561  ...
# 2019                16.575049   6.897379 -1.248411  -1.135503   3.652374  ...
# 2020                21.227716  13.267405  6.021863 -20.652095  -8.438547  ...
# 2021                22.794773  11.726012  7.416543 -26.601984  21.674526  ...
# 2022                -6.018658  -8.677738 -0.198323  -2.503067  -1.397327  ...
# 2023                -7.009165  10.887762 -2.284877  -4.678409   1.007306  ...
# Avg                  7.672484   7.794578  0.340631  -8.762710  -0.053538  ...
# Median               7.520119  11.306887 -0.723367  -3.590738  -0.195011  ...
#
# unique_week_number   K-M11-W1   K-M11-W2   K-M11-W3  K-M11-W4  K-M11-W5  \
# year
# 2017                 3.404587  16.496711  30.322399 -0.548786       NaN
# 2018                 0.193278 -15.818438 -33.718722 -1.753055       NaN
# 2019                 4.092987  -2.720152 -23.860298  7.671977       NaN
# 2020                14.525562  -1.366968  24.987167  2.905202  4.376041
# 2021                 7.582776   0.301566  -7.958284  0.823532 -2.289529
# 2022               -22.111271  -6.491199   4.523687  7.164037       NaN
# 2023                 8.086335  -1.624696   2.528499  6.333097       NaN
# Avg                  2.253465  -1.603311  -0.453650  3.228000  1.043256
# Median               4.092987  -1.624696   2.528499  2.905202  1.043256
#
# unique_week_number   L-M12-W1   L-M12-W2   L-M12-W3   L-M12-W4   L-M12-W5
# year
# 2017                -7.158375  65.587926  -7.012238  11.310282        NaN
# 2018               -20.037726  -9.210808  52.373642   6.773619  11.646470
# 2019                -0.185775  -5.304440  -7.279236   1.695428   0.751712
# 2020                -1.810203   8.017806   7.367184  42.793753        NaN
# 2021                -1.583247  -4.984504   3.552880  -5.790475        NaN
# 2022                -1.281069  -6.329375   2.996467  -1.491974        NaN
# 2023                 7.270082  -6.626027   3.073939   0.787530        NaN
# Avg                 -3.540902   5.878654   7.867520   8.011166   6.199091
# Median              -1.583247  -5.304440   3.073939   1.695428   6.199091
#
# [9 rows x 59 columns]
# Historical Avg:
# unique_week_number
# A-M1-W1      8.945824
# A-M1-W2     10.235574
# A-M1-W3     -5.425974
# A-M1-W4      4.201379
# A-M1-W5     -5.916442
# B-M2-W1      7.672484
# K-M11-W3     2.528499
# K-M11-W4     2.905202
# K-M11-W5     1.043256
# L-M12-W1    -1.583247
# L-M12-W2    -5.304440
# L-M12-W3     3.073939
# L-M12-W4     1.695428
# L-M12-W5     6.199091
# Name: Median, dtype: float64
# Total buy signal weeks: 12
# Total winning weeks: 6
# Win rate for buy signals from previous years: 50.00%
# Total profit of winning weeks: 79.23%
# Total loss of losing weeks: -28.82%

# %%
import ccxt
import pandas as pd
from IPython.display import display, HTML

# Function to fetch ETH/USDT historical data from Binance
def fetch_data(symbol, timeframe='1w', since='2000-01-01T00:00:00Z'):
    exchange = ccxt.binance()
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=exchange.parse8601(since))

    # Convert to DataFrame
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    # Extract year, month, and week for pivot table analysis
    df['year'] = df.index.year
    #delete all 2024 data
    #df = df[df['year'] < 2024]
    df['month'] = df.index.month
    df['week_of_year'] = df.index.isocalendar().week  # Get the week number of the year
    df['week_of_month'] = (df.index.day - 1) // 7 + 1  # Calculate which week of the month
    df['month_week'] = 'M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)

    # Generate a unique "week number" for sorting (unique within the same year)
    # Map months to letters (A = Jan, B = Feb, ..., L = Dec)
    df['month_letter'] = df['month'].apply(lambda x: chr(64 + x))  # Convert month to letter (1 -> A, 2 -> B, ..., 12 -> L)
    # Create unique "week number" format: MonthLetter-MonthNumber-WeekOfMonth
    

    
    # Create unique "week number" format: MonthLetter-WeekOfMonth
    # df['unique_week_number'] = df['month_letter'] + '-W' + df['week_of_month'].astype(str)
    df['unique_week_number'] = df['month_letter'] + '-M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)
    return df

# Function to calculate max drawdown (from open to low)
def calculate_max_drawdown(df):
    df['max_drawdown'] = (df['low'] - df['open']) / df['open'] * 100
    return df

# Function to calculate open-to-high percentage change
def calculate_high_to_open_change(df):
    df['high_to_open_change'] = (df['high'] - df['open']) / df['open'] * 100
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to create and style the pivot table with positive percentages in green
# Function to create and style the pivot table with positive percentages in green
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('unique_week_number')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='year', columns='unique_week_number', aggfunc='mean')

    # Calculate mean, median, max, and min for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)
    max_value = pivot_table.max(axis=0)
    min_value = pivot_table.min(axis=0)

    # Add the average, median, max, and min as the last rows
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value
    pivot_table.loc['Max'] = max_value
    pivot_table.loc['Min'] = min_value

    # Function to color positive values green and negative values red
    def color_positive_negative(val):
        if isinstance(val, (int, float)):
            if val > 0:
                return 'background-color: lightgreen; color: white;'  # Green for positive values
            elif val < 0:
                return 'background-color: pink; color: white;'  # Red for negative values
        return ''  # No change for non-numeric values

    # Style the table
    styled_table = pivot_table.style \
        .format('{:.2f}%') \
        .applymap(color_positive_negative)  # Apply the coloring function to the table
    
    # Set additional styles
    styled_table.set_table_styles([ 
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'), ('color', 'black')]},
        {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#f2f2f2')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ffffff')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%'), ('display', 'block'), ('overflow-x', 'auto'), ('position', 'relative')]},  # Set relative position for the table container
        {'selector': 'th', 'props': [('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px'), ('border', '1px solid #ddd')]},
        {'selector': 'tbody tr', 'props': [('color', 'blue')]},
        
        # Add a line below the "Avg" row to separate it from the rest of the table
        {'selector': 'tr:nth-last-child(5)', 'props': [('border-bottom', '2px solid black')]},  # Row for "Avg"
        
        # # Freeze the first column (Year) and the header row
        # {'selector': 'thead', 'props': [('position', 'sticky'), ('top', '0'), ('z-index', '1')]},  # Freeze header row
        # {'selector': 'thead th:first-child', 'props': [('position', 'sticky'), ('left', '0'), ('background-color', '#f2f2f2'), ('z-index', '2')]},  # Freeze the first column in header
        # {'selector': 'tbody td:first-child', 'props': [('position', 'sticky'), ('left', '0'), ('background-color', '#f2f2f2'), ('z-index', '2')]},  # Freeze the first column in body
    ]) \
    .set_table_attributes('class="dataframe"')

    return styled_table



# Function to display the table with a title
def display_table(title, styled_table):
    display(HTML(f"<h3>{title}</h3>"))
    display(styled_table)

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    ETH_data = fetch_data(symbol)

    # Calculate indicators
    ETH_data = calculate_max_drawdown(ETH_data)
    ETH_data = calculate_high_to_open_change(ETH_data)
    ETH_data = calculate_weekly_return(ETH_data)

    # Create and display the pivot tables
    styled_table_max_drawdown = create_pivot_table(ETH_data, 'max_drawdown')
    display_table("ETH/USDT Weekly Max Drawdown (Month-Letter-WeekOfMonth)", styled_table_max_drawdown)

    styled_table_high_to_open_change = create_pivot_table(ETH_data, 'high_to_open_change')
    display_table("ETH/USDT Weekly Open to High % Change (Month-Letter-WeekOfMonth)", styled_table_high_to_open_change)

    styled_table_weekly_return = create_pivot_table(ETH_data, 'weekly_return')
    display_table("ETH/USDT Weekly Returns (Open to Close, Month-Letter-WeekOfMonth)", styled_table_weekly_return)

# Run the main function
main()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_30724\3674096426.py:84: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Max Drawdown (Month-Letter-WeekOfMonth)</h3>
# <style type="text/css">
# #T_8614c thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_8614c tbody td {
#   text-align: center;
#   color: black;
# }
# #T_8614c tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_8614c tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_8614c table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_8614c th {
#   padding: 8px;
# }
# #T_8614c td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_8614c tbody tr {
#   color: blue;
# }
# #T_8614c tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T_8614c_row0_col35, #T_8614c_row0_col36, #T_8614c_row0_col37, #T_8614c_row0_col39, #T_8614c_row0_col40, #T_8614c_row0_col41, #T_8614c_row0_col42, #T_8614c_row0_col44, #T_8614c_row0_col45, #T_8614c_row0_col46, #T_8614c_row0_col47, #T_8614c_row0_col48, #T_8614c_row0_col49, #T_8614c_row0_col50, #T_8614c_row0_col51, #T_8614c_row0_col52, #T_8614c_row0_col54, #T_8614c_row0_col56, #T_8614c_row0_col57, #T_8614c_row1_col0, #T_8614c_row1_col1, #T_8614c_row1_col2, #T_8614c_row1_col3, #T_8614c_row1_col4, #T_8614c_row1_col5, #T_8614c_row1_col6, #T_8614c_row1_col7, #T_8614c_row1_col8, #T_8614c_row1_col9, #T_8614c_row1_col10, #T_8614c_row1_col11, #T_8614c_row1_col12, #T_8614c_row1_col14, #T_8614c_row1_col15, #T_8614c_row1_col16, #T_8614c_row1_col17, #T_8614c_row1_col18, #T_8614c_row1_col19, #T_8614c_row1_col20, #T_8614c_row1_col21, #T_8614c_row1_col22, #T_8614c_row1_col24, #T_8614c_row1_col25, #T_8614c_row1_col26, #T_8614c_row1_col27, #T_8614c_row1_col29, #T_8614c_row1_col30, #T_8614c_row1_col31, #T_8614c_row1_col32, #T_8614c_row1_col33, #T_8614c_row1_col34, #T_8614c_row1_col35, #T_8614c_row1_col36, #T_8614c_row1_col37, #T_8614c_row1_col39, #T_8614c_row1_col40, #T_8614c_row1_col41, #T_8614c_row1_col42, #T_8614c_row1_col44, #T_8614c_row1_col45, #T_8614c_row1_col46, #T_8614c_row1_col47, #T_8614c_row1_col48, #T_8614c_row1_col49, #T_8614c_row1_col50, #T_8614c_row1_col51, #T_8614c_row1_col52, #T_8614c_row1_col54, #T_8614c_row1_col55, #T_8614c_row1_col56, #T_8614c_row1_col57, #T_8614c_row1_col58, #T_8614c_row2_col0, #T_8614c_row2_col1, #T_8614c_row2_col2
5_col2, #T_3a8c2_row5_col5, #T_3a8c2_row5_col6, #T_3a8c2_row5_col7, #T_3a8c2_row5_col8, #T_3a8c2_row5_col9, #T_3a8c2_row5_col14, #T_3a8c2_row5_col15, #T_3a8c2_row5_col16, #T_3a8c2_row5_col17, #T_3a8c2_row5_col19, #T_3a8c2_row5_col20, #T_3a8c2_row5_col21, #T_3a8c2_row5_col22, #T_3a8c2_row5_col23, #T_3a8c2_row5_col24, #T_3a8c2_row5_col25, #T_3a8c2_row5_col27, #T_3a8c2_row5_col36, #T_3a8c2_row5_col37, #T_3a8c2_row5_col40, #T_3a8c2_row5_col41, #T_3a8c2_row5_col42, #T_3a8c2_row5_col45, #T_3a8c2_row5_col48, #T_3a8c2_row5_col49, #T_3a8c2_row5_col50, #T_3a8c2_row5_col54, #T_3a8c2_row5_col55, #T_3a8c2_row5_col57, #T_3a8c2_row6_col4, #T_3a8c2_row6_col5, #T_3a8c2_row6_col7, #T_3a8c2_row6_col8, #T_3a8c2_row6_col11, #T_3a8c2_row6_col16, #T_3a8c2_row6_col20, #T_3a8c2_row6_col23, #T_3a8c2_row6_col24, #T_3a8c2_row6_col25, #T_3a8c2_row6_col29, #T_3a8c2_row6_col31, #T_3a8c2_row6_col32, #T_3a8c2_row6_col33, #T_3a8c2_row6_col35, #T_3a8c2_row6_col36, #T_3a8c2_row6_col37, #T_3a8c2_row6_col39, #T_3a8c2_row6_col41, #T_3a8c2_row6_col44, #T_3a8c2_row6_col45, #T_3a8c2_row6_col50, #T_3a8c2_row6_col55, #T_3a8c2_row7_col0, #T_3a8c2_row7_col2, #T_3a8c2_row7_col3, #T_3a8c2_row7_col10, #T_3a8c2_row7_col11, #T_3a8c2_row7_col14, #T_3a8c2_row7_col15, #T_3a8c2_row7_col16, #T_3a8c2_row7_col18, #T_3a8c2_row7_col19, #T_3a8c2_row7_col22, #T_3a8c2_row7_col24, #T_3a8c2_row7_col25, #T_3a8c2_row7_col26, #T_3a8c2_row7_col29, #T_3a8c2_row7_col32, #T_3a8c2_row7_col33, #T_3a8c2_row7_col34, #T_3a8c2_row7_col37, #T_3a8c2_row7_col39, #T_3a8c2_row7_col43, #T_3a8c2_row7_col46, #T_3a8c2_row7_col47, #T_3a8c2_row7_col50, #T_3a8c2_row7_col55, #T_3a8c2_row8_col2, #T_3a8c2_row8_col4, #T_3a8c2_row8_col8, #T_3a8c2_row8_col10, #T_3a8c2_row8_col12, #T_3a8c2_row8_col21, #T_3a8c2_row8_col24, #T_3a8c2_row8_col25, #T_3a8c2_row8_col30,  ...
#   background-color: pink;
#   color: white;
# }
# #T_3a8c2_row0_col36, #T_3a8c2_row0_col41, #T_3a8c2_row0_col42, #T_3a8c2_row0_col44, #T_3a8c2_row0_col45, #T_3a8c2_row0_col47, #T_3a8c2_row0_col49, #T_3a8c2_row0_col50, #T_3a8c2_row0_col51, #T_3a8c2_row0_col55, #T_3a8c2_row0_col57, #T_3a8c2_row1_col0, #T_3a8c2_row1_col1, #T_3a8c2_row1_col3, #T_3a8c2_row1_col6, #T_3a8c2_row1_col8, #T_3a8c2_row1_col14, #T_3a8c2_row1_col15, #T_3a8c2_row1_col16, #T_3a8c2_row1_col17, #T_3a8c2_row1_col18, #T_3a8c2_row1_col22, #T_3a8c2_row1_col29, #T_3a8c2_row1_col31, #T_3a8c2_row1_col32, #T_3a8c2_row1_col37, #T_3a8c2_row1_col40, #T_3a8c2_row1_col41, #T_3a8c2_row1_col46, #T_3a8c2_row1_col48, #T_3a8c2_row1_col49, #T_3a8c2_row1_col56, #T_3a8c2_row1_col57, #T_3a8c2_row1_col58, #T_3a8c2_row2_col1, #T_3a8c2_row2_col5, #T_3a8c2_row2_col6, #T_3a8c2_row2_col9, #T_3a8c2_row2_col10, #T_3a8c2_row2_col12, #T_3a8c2_row2_col14, #T_3a8c2_row2_col16, #T_3a8c2_row2_col18, #T_3a8c2_row2_col19, #T_3a8c2_row2_col20, #T_3a8c2_row2_col21, #T_3a8c2_row2_col22, #T_3a8c2_row2_col25, #T_3a8c2_row2_col26, #T_3a8c2_row2_col29, #T_3a8c2_row2_col33, #T_3a8c2_row2_col39, #T_3a8c2_row2_col40, #T_3a8c2_row2_col41, #T_3a8c2_row2_col43, #T_3a8c2_row2_col44, #T_3a8c2_row2_col46, #T_3a8c2_row2_col49, #T_3a8c2_row2_col52, #T_3a8c2_row2_col57, #T_3a8c2_row2_col58, #T_3a8c2_row3_col0, #T_3a8c2_row3_col1, #T_3a8c2_row3_col2, #T_3a8c2_row3_col3, #T_3a8c2_row3_col5, #T_3a8c2_row3_col6, #T_3a8c2_row3_col7, #T_3a8c2_row3_col12, #T_3a8c2_row3_col13, #T_3a8c2

# %%
import ccxt
import pandas as pd
from IPython.display import display, HTML
from datetime import timedelta

# Function to fetch ETH/USDT historical data from Binance
def fetch_data(symbol, timeframe='1w', since='2000-01-01T00:00:00Z'):
    exchange = ccxt.binance()
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=exchange.parse8601(since))

    # Convert to DataFrame
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    # Extract year, month, and week for pivot table analysis
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['week_of_year'] = df.index.isocalendar().week  # Get the week number of the year
    df['week_of_month'] = (df.index.day - 1) // 7 + 1  # Calculate which week of the month
    df['month_week'] = 'M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)

    # Generate a unique "week number" for sorting (unique within the same year)
    df['month_letter'] = df['month'].apply(lambda x: chr(64 + x))  # Convert month to letter (1 -> A, 2 -> B, ..., 12 -> L)
    # Create unique "week number" format: MonthLetter-MonthNumber-WeekOfMonth
    df['unique_week_number'] = df['month_letter'] + '-M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)
    
    return df

# Function to filter data for the 18 months after each halving event
def filter_halving_data(df):
    halving_dates = ['2012-11-28', '2016-07-10', '2020-05-12', '2024-04-20']
    halving_dates = pd.to_datetime(halving_dates)

    # Filter the DataFrame to only include data from 18 months after each halving date
    filtered_df = pd.DataFrame()
    for halving_date in halving_dates:
        start_date = halving_date
        end_date = start_date + timedelta(weeks=18*4)  # 18 months = 18 * 4 weeks
        filtered_df = pd.concat([filtered_df, df[(df.index >= start_date) & (df.index <= end_date)]])

    return filtered_df

# Function to calculate max drawdown (from open to low)
def calculate_max_drawdown(df):
    df['max_drawdown'] = (df['low'] - df['open']) / df['open'] * 100
    return df

# Function to calculate open-to-high percentage change
def calculate_high_to_open_change(df):
    df['high_to_open_change'] = (df['high'] - df['open']) / df['open'] * 100
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to add the halving week number and halving count columns
def add_halving_columns(df):
    halving_dates = pd.to_datetime(['2012-11-28', '2016-07-10', '2020-05-12', '2024-04-20'])
    halving_counts = [1, 2, 3, 4]
    
    # Create new columns to store the week after halving and halving count
    df['week_after_halving'] = None
    df['halving_count'] = None

    # Iterate over each halving event
    for i, halving_date in enumerate(halving_dates):
        # Calculate the weeks since each halving event
        df.loc[df.index >= halving_date, 'week_after_halving'] = ((df.index[df.index >= halving_date] - halving_date).days // 7) + 1
        df.loc[df.index >= halving_date, 'halving_count'] = halving_counts[i]
    
    return df

# Function to create and style the pivot table with positive percentages in green
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('week_after_halving')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='halving_count', columns='week_after_halving', aggfunc='mean')

    # Calculate mean, median, max, and min for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)
    max_value = pivot_table.max(axis=0)
    min_value = pivot_table.min(axis=0)

    # Add the average, median, max, and min as the last rows
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value
    pivot_table.loc['Max'] = max_value
    pivot_table.loc['Min'] = min_value

    # Function to color positive values green and negative values red
    def color_positive_negative(val):
        if isinstance(val, (int, float)):
            if val > 0:
                return 'background-color: lightgreen; color: white;'  # Green for positive values
            elif val < 0:
                return 'background-color: pink; color: white;'  # Red for negative values
        return ''  # No change for non-numeric values

    # Style the table
    styled_table = pivot_table.style \
        .format('{:.2f}%') \
        .applymap(color_positive_negative)  # Apply the coloring function to the table
    
    # Set additional styles
    styled_table.set_table_styles([ 
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'), ('color', 'black')]},
        {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#f2f2f2')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ffffff')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%'), ('display', 'block'), ('overflow-x', 'auto'), ('position', 'relative')]},  # Set relative position for the table container
        {'selector': 'th', 'props': [('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px'), ('border', '1px solid #ddd')]},
        {'selector': 'tbody tr', 'props': [('color', 'blue')]},
        
        # Add a line below the "Avg" row to separate it from the rest of the table
        {'selector': 'tr:nth-last-child(5)', 'props': [('border-bottom', '2px solid black')]},  # Row for "Avg"
    ]) \
    .set_table_attributes('class="dataframe"')

    return styled_table

# Function to display the table with a title
def display_table(title, styled_table):
    display(HTML(f"<h3>{title}</h3>"))
    display(styled_table)

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    ETH_data = fetch_data(symbol)

    # Filter data for 18 months after each halving
    ETH_data = filter_halving_data(ETH_data)

    # Add halving week and halving count columns
    ETH_data = add_halving_columns(ETH_data)

    # Calculate indicators
    ETH_data = calculate_max_drawdown(ETH_data)
    ETH_data = calculate_high_to_open_change(ETH_data)
    ETH_data = calculate_weekly_return(ETH_data)

    # Create and display the pivot tables
    styled_table_high_to_open_change = create_pivot_table(ETH_data, 'high_to_open_change')
    display_table("ETH/USDT Weekly Open to High % Change (Week After Halving)", styled_table_high_to_open_change)
    styled_table_max_drawdown = create_pivot_table(ETH_data, 'max_drawdown')
    display_table("ETH/USDT Weekly Max Drawdown (Week After Halving)", styled_table_max_drawdown)

    styled_table_weekly_return = create_pivot_table(ETH_data, 'weekly_return')
    display_table("ETH/USDT Weekly Returns (Open to Close, Week After Halving)", styled_table_weekly_return)

# Run the main function
main()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\2122496671.py:108: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Open to High % Change (Week After Halving)</h3>
# <style type="text/css">
# #T_e8b6f thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_e8b6f tbody td {
#   text-align: center;
#   color: black;
# }
# #T_e8b6f tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_e8b6f tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_e8b6f table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_e8b6f th {
#   padding: 8px;
# }
# #T_e8b6f td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_e8b6f tbody tr {
#   color: blue;
# }
# #T_e8b6f tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to create a heatmap-style pivot table
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('unique_week_number')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='year', columns='unique_week_number', aggfunc='mean')

    # Calculate mean and median for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)

    # Add the average and median as the last row
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value

    # Apply color gradients for heatmap (Green for positive, Red for negative)
    def color_map(val):
        color = 'white'  # Default color for no value
        if isinstance(val, (int, float)):  # Check if value is numeric
            if val > 0:
                color = f'rgb({255 - int(val*2.5)}, 255, {255 - int(val*2.5)})'  # Green shades for positive
            elif val < 0:
                color = f'rgb(255, {255 + int(val*2.5)}, {255 - int(abs(val)*2.5)})'  # Red shades for negative
        return f'background-color: {color};'

    # Apply heatmap coloring
    styled_table = pivot_table.style \
        .applymap(color_map)  # Apply the heatmap color function to each cell

    # Additional table styling
    styled_table = styled_table.set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'), ('color', 'black')]},
        {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#f2f2f2')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ffffff')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%')]},
        {'selector': 'th', 'props': [('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px'), ('border', '1px solid #ddd')]},
        {'selector': 'tbody tr', 'props': [('color', 'blue')]},
    ]) \
    .set_table_attributes('class="dataframe"')

    return styled_table

# Function to display the table with a title
def display_table(title, styled_table):
    display(HTML(f"<h3>{title}</h3>"))
    display(styled_table)

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    eth_data = fetch_data(symbol)

    # Calculate indicators
    eth_data = calculate_max_drawdown(eth_data)
    eth_data = calculate_high_to_open_change(eth_data)
    eth_data = calculate_weekly_return(eth_data)

    # Create and display the pivot tables with heatmap style
    styled_table_max_drawdown = create_pivot_table(eth_data, 'max_drawdown')
    display_table("ETH/USDT Weekly Max Drawdown Heatmap (Month-Letter-WeekOfMonth)", styled_table_max_drawdown)

    styled_table_high_to_open_change = create_pivot_table(eth_data, 'high_to_open_change')
    display_table("ETH/USDT Weekly Open to High % Change Heatmap (Month-Letter-WeekOfMonth)", styled_table_high_to_open_change)

    styled_table_weekly_return = create_pivot_table(eth_data, 'weekly_return')
    display_table("ETH/USDT Weekly Returns Heatmap (Open to Close, Month-Letter-WeekOfMonth)", styled_table_weekly_return)

# Run the main function
main()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\2132610971.py:71: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_map)  # Apply the heatmap color function to each cell
# <h3>ETH/USDT Weekly Max Drawdown Heatmap (Month-Letter-WeekOfMonth)</h3>
# <style type="text/css">
# #T_eb1f4 thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_eb1f4 tbody td {
#   text-align: center;
#   color: black;
# }
# #T_eb1f4 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_eb1f4 tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_eb1f4 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_eb1f4 th {
#   padding: 8px;
# }
# #T_eb1f4 td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_eb1f4 tbody tr {
#   color: blue;
# }
# #T_eb1f4_row0_col0, #T_eb1f4_row0_col1, #T_eb1f4_row0_col2, #T_eb1f4_row0_col3, #T_eb1f4_row0_col4, #T_eb1f4_row0_col5, #T_eb1f4_row0_col6, #T_eb1f4_row0_col7, #T_eb1f4_row0_col8, #T_eb1f4_row0_col9, #T_eb1f4_row0_col10, #T_eb1f4_row0_col11, #T_eb1f4_row0_col12, #T_eb1f4_row0_col13, #T_eb1f4_row0_col14, #T_eb1f4_row0_col15, #T_eb1f4_row0_col16, #T_eb1f4_row0_col17, #T_eb1f4_row0_col18, #T_eb1f4_row0_col19, #T_eb1f4_row0_col20, #T_eb1f4_row0_col21, #T_eb1f4_row0_col22, #T_eb1f4_row0_col23, #T_eb1f4_row0_col24, #T_eb1f4_row0_col25, #T_eb1f4_row0_col26, #T_eb1f4_row0_col27, #T_eb1f4_row0_col28, #T_eb1f4_row0_col29, #T_eb1f4_row0_col30, #T_eb1f4_row0_col31, #T_eb1f4_row0_col32, #T_eb1f4_row0_col33, #T_eb1f4_row0_col34, #T_eb1f4_row0_col38, #T_eb1f4_row0_col43, #T_eb1f4_row0_col53, #T_eb1f4_row0_col55, #T_eb1f4_row0_col58, #T_eb1f4_row1_col13, #T_eb1f4_row1_col23, #T_eb1f4_row1_col28, #T_eb1f4_row1_col38, #T_eb1f4_row1_col43, #T_eb1f4_row1_col53, #T_eb1f4_row2_col4, #T_eb1f4_row2_col13, #T_eb1f4_row2_col23, #T_eb1f4_row2_col28, #T_eb1f4_row2_col38, #T_eb1f4_row2_col48, #T_eb1f4_row2_col53, #T_eb1f4_row3_col4, #T_eb1f4_row3_col18, #T_eb1f4_row3_col23, #T_eb1f4_row3_col33, #T_eb1f4_row3_col43, #T_eb1f4_row3_col48, #T_eb1f4_row3_col58, #T_eb1f4_row4_col4, #T_eb1f4_row4_col18, #T_eb1f4_row4_col28, #T_eb1f4_row4_col33, #T_eb1f4_row4_col43, #T_eb1f4_row4_col48, #T_eb1f4_row4_col58, #T_eb1f4_row5_col13, #T_eb1f4_row5_col18, #T_eb1f4_row5_col28, #T_eb1f4_row5_col33, #T_eb1f4_row5_col43, #T_eb1f4_row5_col53, #T_eb1f4_row5_col58, #T_eb1f4_row6_col13, #T_eb1f4_row6_col18, #T_eb1f4_row6_col28, #T_eb1f4_row6_col38, #T_eb1f4_row6_col43, #T_eb1f4_row6_col53, #T_eb1f4_row6_col58, #T_eb1f4_row7_col13, #T_eb1f4_row7_col23, #T_eb1f4_row7_col28, #T_eb1f4_row7_col38, #T_eb1f4_row7_col48, #T_eb1f4_row7_col53, #T_eb1f4_row7_col56, #T_eb1f4_row7_col57, #T_eb1f4_row7_col58 {
#   background-color: white;
# }
# #T_eb1f4_row0_col35, #T_eb1f4_row0_col45, #T_eb1f4_row2_col36, #T_eb1f4_row2_col57, #T_eb1f4_row5_col15, #T_eb1f4_row7_col0, #T_eb1f4_row8_col15, #T_eb1f4_row8_col16, #T_eb1f4_row8_col43, #T_eb1f4_row8_col55, #T_eb1f4_row9_col0, #T_eb1f4_row9_col15, #T_eb1f4_row9_col43, #T_eb1f4_row9_col57 {
#   background-color: rgb(255, 236, 236);
# }
# #T_eb1f4_row0_col36, #T_eb1f4_row4_col21 {
#   background-color: rgb(255, 126, 126);
# }
# #T_eb1f4_row0_col37, #T_eb1f4_row3_col47, #T_eb1f4_row4_col7, #T_eb1f4_row4_col16, #T_eb1f4_row4_col52, #T_eb1f4_row7_col9, #T_eb1f4_row7_col19, #T_eb1f4_row8_col5, #T_eb1f4_row8_col11, #T_eb1f4_row8_col41, #T_eb1f4_row9_col9, #T_eb1f4_row9_col19 {
#   background-color: rgb(255, 235, 235);
# }
# #T_eb1f4_row0_col39, #T_eb1f4_row1_col5 {
#   background-color: rgb(255, 179, 179);
# }
# #T_eb1f4_row0_col40 {
#   background-color: rgb(255, 169, 169);
# }
# #T_eb1f4_row0_col41, #T_eb1f4_row1_col0, #T_eb1f4_row1_col31, #T_eb1f4_row1_col32, #T_eb1f4_row1_col49, #T_eb1f4_row2_col26, #T_eb1f4_row3_col5, #T_eb1f4_row3_col12, #T_eb1f4_row3_col31, #T_eb1f4_row6_col39, #T_eb1f4_row6_col49, #T_eb1f4_row7_col2, #T_eb1f4_row7_col20, #T_eb1f4_row9_col31 {
#   background-color: rgb(255, 250, 250);
# }
# #T_eb1f4_row0_col42, #T_eb1f4_row3_col1, #T_eb1f4_row3_col24, #T_eb1f4_row3_col40, #T_eb1f4_row3_col53, #T_eb1f4_row4_col6, #T_eb1f4_row5_col8, #T_eb1f4_row5_col42, #T_eb1f4_row5_col47, #T_eb1f4_row5_col57, #T_eb1f4_row6_col32, #T_eb1f4_row7_col36, #T_eb1f4_row9_col1, #T_eb1f4_row9_col32 {
#   background-color: rgb(255, 248, 248);
# }
# #T_eb1f4_row0_col44, #T_eb1f4_row1_col16, #T_eb1f4_row1_col44, #T_eb1f4_row2_col16, #T_eb1f4_row2_col29, #T_eb1f4_row2_col45, #T_eb1f4_row4_col14, #T_eb1f4_row5_col1, #T_eb1f4_row5_col5, #T_eb1f4_row5_col34, #T_eb1f4_row6_col20, #T_eb1f4_row6_col45, #T_eb1f4_row6_col50, #T_eb1f4_row8_col7, #T_eb1f4_row8_col32, #T_eb1f4_row8_col46, #T_eb1f4_row8_col49, #T_eb1f4_row8_col57, #T_eb1f4_row9_col20, #T_eb1f4_row9_col34, #T_eb1f4_row9_col35, #T_eb1f4_row9_col37, #T_eb1f4_row9_col40, #T_eb1f4_row9_col45, #T_eb1f4_row9_col52, #T_eb1f4_row9_col54 {
#   background-color: rgb(255, 238, 238);
# }
# #T_eb1f4_row0_col46, #T_eb1f4_row1_col26, #T_eb1f4_row2_col24, #T_eb1f4_row6_col35, #T_eb1f4_row8_col36, #T_eb1f4_row9_col24 {
#   background-color: rgb(255, 216, 216);
# }
# #T_eb1f4_row0_col47, #T_eb1f4_row2_col55, #T_eb1f4_row3_col16, #T_eb1f4_row3_col21, #T_eb1f4_row3_col25, #T_eb1f4_row4_col11, #T_eb1f4_row5_col17, #T_eb1f4_row5_col26, #T_eb1f4_row5_col50, #T_eb1f4_row6_col7, #T_eb1f4_row6_col25, #T_eb1f4_row6_col44, #T_eb1f4_row7_col26, #T_eb1f4_row8_col27, #T_eb1f4_row8_col37, #T_eb1f4_row9_col7, #T_eb1f4_row9_col16, #T_eb1f4_row9_col26 {
#   background-color: rgb(255, 237, 237);
# }
# #T_eb1f4_row0_col48, #T_eb1f4_row2_col3, #T_eb1f4_row4_col31, #T_eb1f4_row8_col0, #T_eb1f4_row8_col9, #T_eb1f4_row8_col35, #T_eb1f4_row9_col39 {
#   background-color: rgb(255, 231, 231);
# }
# #T_eb1f4_row0_col49, #T_eb1f4_row2_col10, #T_eb1f4_row2_col54, #T_eb1f4_row5_col4, #T_eb1f4_row6_col12, #T_eb1f4_row8_col17, #T_eb1f4_row9_col10, #T_eb1f4_row9_col42, #T_eb1f4_row9_col44, #T_eb1f4_row9_col51 {
#   background-color: rgb(255, 243, 243);
# }
# #T_eb1f4_row0_col50, #T_eb1f4_row1_col6, #T_eb1f4_row1_col56, #T_eb1f4_row2_col1, #T_eb1f4_row2_col41, #T_eb1f4_row3_col0, #T_eb1f4_row3_col13, #T_eb1f4_row3_col14, #T_eb1f4_row3_col29, #T_eb1f4_row4_col19, #T_eb1f4_row5_col31, #T_eb1f4_row5_col38, #T_eb1f4_row6_col1, #T_eb1f4_row6_col47, #T_eb1f4_row6_col54, #T_eb1f4_row7_col31 {
#   background-color: rgb(255, 255, 255);
# }
# #T_eb1f4_row0_col51, #T_eb1f4_row2_col7, #T_eb1f4_row2_col14, #T_eb1f4_row2_col20, #T_eb1f4_row3_col22, #T_eb1f4_row4_col45, #T_eb1f4_row6_col21, #T_eb1f4_row6_col26, #T_eb1f4_row6_col34, #T_eb1f4_row7_col6, #T_eb1f4_row7_col51 {
#   background-color: rgb(255, 252, 252);
# }
# #T_eb1f4_row0_col52, #T_eb1f4_row4_col24 {
#   background-color: rgb(255, 213, 213);
# }
# #T_eb1f4_row0_col54, #T_eb1f4_row4_col25, #T_eb1f4_row4_col53 {
#   background-color: rgb(255, 209, 209);
# }
# #T_eb1f4_row0_col56, #T_eb1f4_row5_col20 {
#   background-color: rgb(255, 184, 184);
# }
# #T_eb1f4_row0_col57, #T_eb1f4_row1_col18, #T_eb1f4_row2_col22, #T_eb1f4_row4_col0, #T_eb1f4_row4_col42, #T_eb1f4_row6_col55, #T_eb1f4_row7_col16, #T_eb1f4_row8_col18, #T_eb1f4_row8_col19, #T_eb1f4_row8_col26, #T_eb1f4_row9_col18, #T_eb1f4_row9_col33 {
#   background-color: rgb(255, 233, 233);
# }
# #T_eb1f4_row1_col1, #T_eb1f4_row1_col24 {
#   background-color: rgb(255, 208, 208);
# }
# #T_eb1f4_row1_col2 {
#   background-color: rgb(255, 146, 146);
# }
# #T_eb1f4_row1_col3, #T_eb1f4_row1_col36, #T_eb1f4_row4_col3, #T_eb1f4_row7_col46 {
#   background-color: rgb(255, 222, 222);
# }
# #T_eb1f4_row1_col4, #T_eb1f4_row1_col10, #T_eb1f4_row1_col39 {
#   background-color: rgb(255, 162, 162);
# }
# #T_eb1f4_row1_col7, #T_eb1f4_row1_col52, #T_eb1f4_row1_col57, #T_eb1f4_row3_col56, #T_eb1f4_row4_col12, #T_eb1f4_row4_col30, #T_eb1f4_row5_col30, #T_eb1f4_row6_col16, #T_eb1f4_row7_col18, #T_eb1f4_row8_col25, #T_eb1f4_row9_col30 {
#   background-color: rgb(255, 221, 221);
# }
#   background-color: rgb(243, 255, 243);
# }
# #T_99e82_row0_col47, #T_99e82_row1_col7, #T_99e82_row3_col45, #T_99e82_row3_col50, #T_99e82_row4_col25, #T_99e82_row4_col50, #T_99e82_row5_col41, #T_99e82_row6_col17, #T_99e82_row6_col37, #T_99e82_row7_col10, #T_99e82_row8_col2, #T_99e82_row8_col39, #T_99e82_row9_col50 {
#   background-color: rgb(242, 255, 242);
# }
# #T_99e82_row0_col49, #T_99e82_row0_col52, #T_99e82_row3_col46, #T_99e82_row3_col52, #T_99e82_row4_col20, #T_99e82_row4_col53, #T_99e82_row5_col6, #T_99e82_row7_col30, #T_99e82_row7_col52, #T_99e82_row8_col17, #T_99e82_row8_col19 {
#   background-color: rgb(227, 255, 227);
# }
# #T_99e82_row0_col50, #T_99e82_row4_col32 {
#   background-color: rgb(198, 255, 198);
# }
# #T_99e82_row0_col51 {
#   background-color: rgb(164, 255, 164);
# }
# #T_99e82_row0_col54, #T_99e82_row1_col32, #T_99e82_row2_col33, #T_99e82_row5_col24, #T_99e82_row6_col22, #T_99e82_row6_col51, #T_99e82_row8_col44, #T_99e82_row9_col32, #T_99e82_row9_col35, #T_99e82_row9_col44, #T_99e82_row9_col48 {
#   background-color: rgb(240, 255, 240);
# }
# #T_99e82_row0_col55 {
#   background-color: rgb(68, 255, 68);
# }
# #T_99e82_row0_col56, #T_99e82_row1_col57, #T_99e82_row3_col5, #T_99e82_row4_col9, #T_99e82_row7_col1, #T_99e82_row9_col1 {
#   background-color: rgb(200, 255, 200);
# }
# #T_99e82_row1_col0 {
#   background-color: rgb(122, 255, 122);
# }
# #T_99e82_row1_col1 {
#   background-color: rgb(185, 255, 185);
# }
# #T_99e82_row1_col2, #T_99e82_row1_col10, #T_99e82_row1_col25, #T_99e82_row2_col11, #T_99e82_row5_col49, #T_99e82_row6_col21, #T_99e82_row6_col34, #T_99e82_row7_col19, #T_99e82_row7_col29, #T_99e82_row9_col21, #T_99e82_row9_col33 {
#   background-color: rgb(249, 255, 249);
# }
# #T_99e82_row1_col3, #T_99e82_row5_col30, #T_99e82_row5_col47 {
#   background-color: rgb(201, 255, 201);
# }
# #T_99e82_row1_col4, #T_99e82_row1_col9, #T_99e82_row1_col12, #T_99e82_row1_col19, #T_99e82_row1_col21, #T_99e82_row1_col30, #T_99e82_row1_col33, #T_99e82_row1_col42, #T_99e82_row1_col50, #T_99e82_row2_col3, #T_99e82_row2_col24, #T_99e82_row2_col50, #T_99e82_row2_col55, #T_99e82_row4_col26, #T_99e82_row4_col39, #T_99e82_row4_col41, #T_99e82_row5_col20, #T_99e82_row6_col24, #T_99e82_row6_col31, #T_99e82_row6_col44, #T_99e82_row7_col18, #T_99e82_row7_col32, #T_99e82_row7_col37 {
#   background-color: rgb(254, 255, 254);
# }
# #T_99e82_row1_col6 {
#   background-color: rgb(203, 255, 203);
# }
# #T_27d68_row0_col48, #T_27d68_row1_col44, #T_27d68_row2_col45, #T_27d68_row5_col41, #T_27d68_row9_col36 {
#   background-color: rgb(255, 248, 248);
# }
# #T_27d68_row0_col49, #T_27d68_row1_col48, #T_27d68_row2_col18, #T_27d68_row4_col56, #T_27d68_row6_col14, #T_27d68_row8_col20, #T_27d68_row8_col41, #T_27d68_row8_col47, #T_27d68_row9_col18, #T_27d68_row9_col41, #T_27d68_row9_col51 {
#   background-color: rgb(247, 255, 247);
# }
# #T_27d68_row0_col50, #T_27d68_row2_col5, #T_27d68_row4_col32, #T_27d68_row5_col47 {
#   background-color: rgb(214, 255, 214);
# }
# #T_27d68_row0_col51, #T_27d68_row3_col31 {
#   background-color: rgb(180, 255, 180);
# }
# #T_27d68_row0_col54, #T_27d68_row0_col56, #T_27d68_row6_col5, #T_27d68_row9_col33 {
#   background-color: rgb(255, 238, 238);
# }
# #T_27d68_row0_col55 {
#   background-color: rgb(92, 255, 92);
# }
# #T_27d68_row0_col57, #T_27d68_row1_col17, #T_27d68_row7_col1, #T_27d68_row7_col9, #T_27d68_row7_col41, #T_27d68_row7_col45, #T_27d68_row9_col1 {
#   background-color: rgb(227, 255, 227);
# }
# #T_27d68_row1_col0 {
#   background-color: rgb(122, 255, 122);
# }
# #T_27d68_row1_col1, #T_27d68_row3_col32 {
#   background-color: rgb(206, 255, 206);
# }
# #T_27d68_row1_col2, #T_27d68_row1_col34, #T_27d68_row5_col49 {
#   background-color: rgb(255, 200, 200);
# }
# #T_27d68_row1_col3, #T_27d68_row5_col31 {
#   background-color: rgb(207, 255, 207);
# }
# #T_27d68_row1_col4 {
#   background-color: rgb(255, 170, 170);
# }
# #T_27d68_row1_col5, #T_27d68_row2_col7, #T_27d68_row2_col47, #T_27d68_row3_col11, #T_27d68_row3_col26, #T_27d68_row3_col27, #T_27d68_row3_col30, #T_27d68_row3_col42, #T_27d68_row3_col50, #T_27d68_row4_col54, #T_27d68_row5_col9, #T_27d68_row5_col42, #T_27d68_row5_col45, #T_27d68_row5_col48, #T_27d68_row5_col54, #T_27d68_row5_col57, #T_27d68_row6_col32, #T_27d68_row6_col36, #T_27d68_row6_col37, #T_27d68_row9_col26, #T_27d68_row9_col30, #T_27d68_row9_col37, #T_27d68_row9_col54 {
#   background-color: rgb(255, 252, 252);
# }
# #T_27d68_row1_col6, #T_27d68_row4_col45, #T_27d68_row6_col10 {
#   background-color: rgb(224, 255, 224);
# }
# #T_27d68_row1_col7, #T_27d68_row4_col29, #T_27d68_row4_col51 {
#   background-color: rgb(255, 236, 236);
# }
# #T_27d68_row1_col8, #T_27d68_row2_col1, #T_27d68_row3_col52, #T_27d68_row5_col56, #T_27d68_row6_col30, #T_27d68_row6_col56, #T_27d68_row7_col42, #T_27d68_row9_col56 {
#   background-color: rgb(248, 255, 248);
# }
# #T_27d68_row1_col9 {
#   background-color: rgb(255, 213, 213);
# }
# #T_27d68_row1_col10 {
#   background-color: rgb(255, 192, 192);
# }
# #T_27d68_row1_col11, #T_27d68_row2_col34, #T_27d68_row2_col50, #T_27d68_row5_col8, #T_27d68_row6_col41, #T_27d68_row7_col0, #T_27d68_row8_col30, #T_27d68_row8_col36, #T_27d68_row8_col40, #T_27d68_row9_col8 {
#   background-color: rgb(255, 249, 249);
# }
# #T_27d68_row1_col12 {
#   background-color: rgb(255, 186, 186);
# }
# #T_27d68_row1_col14, #T_27d68_row3_col24, #T_27d68_row6_col22, #T_27d68_row8_col49, #T_27d68_row9_col22, #T_27d68_row9_col49 {
#   background-color: rgb(241, 255, 241);
# }
# #T_27d68_row1_col15 {
#   background-color: rgb(172, 255, 172);
# }
# #T_27d68_row1_col18, #T_27d68_row5_col11, #T_27d68_row7_col6 {
#   background-color: rgb(218, 255, 218);
# }
# #T_27d68_row1_col19, #T_27d68_row1_col36, #T_27d68_row4_col41, #T_27d68_row7_col3, #T_27d68_row7_col43 {
#   background-color: rgb(255, 235, 235);
# }
# #T_27d68_row1_col21, #T_27d68_row1_col54 {
#   background-color: rgb(255, 205, 205);
# }
# #T_27d68_row1_col24 {
#   background-color: rgb(255, 217, 217);
# }
# #T_27d68_row1_col25, #T_27d68_row2_col55, #T_27d68_row3_col25, #T_27d68_row4_col12, #T_27d68_row7_col11, #T_27d68_row7_col14, #T_27d68_row7_col39, #T_27d68_row9_col25 {
#   background-color: rgb(255, 242, 242);
# }
# #T_27d68_row1_col26, #T_27d68_row2_col37, #T_27d68_row3_col9, #T_27d68_row4_col20, #T_27d68_row5_col6, #T_27d68_row6_col35, #T_27d68_row7_col15, #T_27d68

# %%
import ccxt
import pandas as pd
from IPython.display import display, HTML
from datetime import timedelta

# Function to fetch ETH/USDT historical data from Binance
def fetch_data(symbol, timeframe='1w', since='2000-01-01T00:00:00Z'):
    exchange = ccxt.binance()
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=exchange.parse8601(since))

    # Convert to DataFrame
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    # Extract year, month, and week for pivot table analysis
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['week_of_year'] = df.index.isocalendar().week  # Get the week number of the year
    df['week_of_month'] = (df.index.day - 1) // 7 + 1  # Calculate which week of the month
    df['month_week'] = 'M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)

    # Generate a unique "week number" for sorting (unique within the same year)
    df['month_letter'] = df['month'].apply(lambda x: chr(64 + x))  # Convert month to letter (1 -> A, 2 -> B, ..., 12 -> L)
    # Create unique "week number" format: MonthLetter-MonthNumber-WeekOfMonth
    df['unique_week_number'] = df['month_letter'] + '-M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)
    return df

# Function to filter data for the 18 months after each halving event
def filter_halving_data(df):
    halving_dates = ['2012-11-28', '2016-07-10', '2020-05-12', '2024-04-20']
    halving_dates = pd.to_datetime(halving_dates)

    # Filter the DataFrame to only include data from 18 months after each halving date
    filtered_df = pd.DataFrame()
    for halving_date in halving_dates:
        start_date = halving_date
        end_date = start_date + timedelta(weeks=18*4)  # 18 months = 18 * 4 weeks
        filtered_df = pd.concat([filtered_df, df[(df.index >= start_date) & (df.index <= end_date)]])

    return filtered_df

# Function to calculate max drawdown (from open to low)
def calculate_max_drawdown(df):
    df['max_drawdown'] = (df['low'] - df['open']) / df['open'] * 100
    return df

# Function to calculate open-to-high percentage change
def calculate_high_to_open_change(df):
    df['high_to_open_change'] = (df['high'] - df['open']) / df['open'] * 100
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to create and style the pivot table with positive percentages in green
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('unique_week_number')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='year', columns='unique_week_number', aggfunc='mean')

    # Calculate mean, median, max, and min for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)
    max_value = pivot_table.max(axis=0)
    min_value = pivot_table.min(axis=0)

    # Add the average, median, max, and min as the last rows
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value
    pivot_table.loc['Max'] = max_value
    pivot_table.loc['Min'] = min_value

    # Function to color positive values green and negative values red
    def color_positive_negative(val):
        if isinstance(val, (int, float)):
            if val > 0:
                return 'background-color: lightgreen; color: white;'  # Green for positive values
            elif val < 0:
                return 'background-color: pink; color: white;'  # Red for negative values
        return ''  # No change for non-numeric values

    # Style the table
    styled_table = pivot_table.style \
        .format('{:.2f}%') \
        .applymap(color_positive_negative)  # Apply the coloring function to the table
    
    # Set additional styles
    styled_table.set_table_styles([ 
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'), ('color', 'black')]},
        {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#f2f2f2')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ffffff')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%'), ('display', 'block'), ('overflow-x', 'auto'), ('position', 'relative')]},  # Set relative position for the table container
        {'selector': 'th', 'props': [('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px'), ('border', '1px solid #ddd')]},
        {'selector': 'tbody tr', 'props': [('color', 'blue')]},
        
        # Add a line below the "Avg" row to separate it from the rest of the table
        {'selector': 'tr:nth-last-child(5)', 'props': [('border-bottom', '2px solid black')]},  # Row for "Avg"
    ]) \
    .set_table_attributes('class="dataframe"')

    return styled_table

# Function to display the table with a title
def display_table(title, styled_table):
    display(HTML(f"<h3>{title}</h3>"))
    display(styled_table)

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    ETH_data = fetch_data(symbol)

    # Filter data for 18 months after each halving
    ETH_data = filter_halving_data(ETH_data)

    # Calculate indicators
    ETH_data = calculate_max_drawdown(ETH_data)
    ETH_data = calculate_high_to_open_change(ETH_data)
    ETH_data = calculate_weekly_return(ETH_data)

    # Create and display the pivot tables
    styled_table_max_drawdown = create_pivot_table(ETH_data, 'max_drawdown')
    display_table("ETH/USDT Weekly Max Drawdown (Month-Letter-WeekOfMonth)", styled_table_max_drawdown)

    styled_table_high_to_open_change = create_pivot_table(ETH_data, 'high_to_open_change')
    display_table("ETH/USDT Weekly Open to High % Change (Month-Letter-WeekOfMonth)", styled_table_high_to_open_change)

    styled_table_weekly_return = create_pivot_table(ETH_data, 'weekly_return')
    display_table("ETH/USDT Weekly Returns (Open to Close, Month-Letter-WeekOfMonth)", styled_table_weekly_return)

# Run the main function
main()


# 第一次减半	2012-11-28	50→25
# 第二次减半	2016-07-10	25→12.5
# 第三次减半	2020-05-12	12.5→6.25
# 第四次减半	2024-04-20	6.25→3.125




# 然後help me build a new col in the df fetched, and name it "減半後的第幾周“（make it english name）

#  find該周是減半後的第幾周然後填入col of the df
# 再create一個col“第幾次減半”

# 然後幫我改變三幅table的code，我要“減半後的第幾周”作為x axis ，第幾次減半作為y axis

# 三個table：
# 應該有大约（18x4）個col （18个月）
# 和4個row（四個減半）
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\1418307944.py:90: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Max Drawdown (Month-Letter-WeekOfMonth)</h3>
# <style type="text/css">
# #T_526a1 thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_526a1 tbody td {
#   text-align: center;
#   color: black;
# }
# #T_526a1 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_526a1 tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_526a1 table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_526a1 th {
#   padding: 8px;
# }
# #T_526a1 td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_526a1 tbody tr {
#   color: blue;
# }
# #T_526a1 tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T_526a1_row0_col34, #T_526a1_row0_col35, #T_526a1_row0_col36, #T_526a1_row0_col38, #T_526a1_row0_col39, #T_526a1_row0_col40, #T_526a1_row0_col41, #T_526a1_row0_col43, #T_526a1_row0_col44, #T_526a1_row0_col45, #T_526a1_row0_col46, #T_526a1_row0_col47, #T_526a1_row0_col48, #T_526a1_row0_col49, #T_526a1_row0_col50, #T_526a1_row1_col20, #T_526a1_row1_col21, #T_526a1_row1_col23, #T_526a1_row1_col24, #T_526a1_row1_col25, #T_526a1_row1_col26,
#T_526a1_row4_col17, #T_526a1_row4_col18, #T_526a1_row4_col19, #T_526a1_row4_col20, #T_526a1_row4_col21, #T_526a1_row4_col22, #T_526a1_row4_col23, #T_526a1_row4_col24, #T_526a1_row4_col25, #T_526a1_row4_col26, #T_526a1_row4_col27, #T_526a1_row4_col28, #T_526a1_row4_col29, #T_526a1_row4_col30, #T_526a1_row4_col31, #T_526a1_row4_col32, #T_526a1_row4_col33, #T_526a1_row4_col34, #T_526a1_row4_col35, #T_526a1_row4_col36, #T_526a1_row4_col37, #T_526a1_row4_col38, #T_526a1_row4_col39, #T_526a1_row4_col40, #T_526a1_row4_col41, #T_526a1_row4_col42, #T_526a1_row4_col43, #T_526a1_row4_col44, #T_526a1_row4_col45, #T_526a1_row4_col46, #T_526a1_row4_col47, #T_526a1_row4_col48, #T_526a1_row4_col49, #T_526a1_row4_col50, #T_526a1_row4_col51, #T_526a1_row4_col52, #T_526a1_row4_col53, #T_526a1_row4_col54, #T_526a1_row4_col55, #T_526a1_row4_col56, #T_526a1_row5_col0, #T_526a1_row5_col1, #T_526a1_row5_col2, #T_526a1_row5_col3, #T_526a1_row5_col4, #T_526a1_row5_col5, #T_526a1_row5_col6, #T_526a1_row5_col7, #T_526a1_row5_col8, #T_526a1_row5_col9, #T_526a1_row5_col10, #T_526a1_row5_col11, #T_526a1_row5_col12, #T_526a1_row5_col13 ...
#   background-color: pink;
#   color: white;
# }
# </style>
# <table id="T_526a1" class="dataframe">
#   <th
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\1418307944.py:90: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Open to High % Change (Month-Letter-WeekOfMonth)</h3>
# <style type="text/css">
# #T_3e2c9 thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_3e2c9 tbody td {
#   text-align: center;
#   color: black;
# }
# #T_3e2c9 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_3e2c9 tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_3e2c9 table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_3e2c9 th {
#   padding: 8px;
# }
# #T_3e2c9 td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_3e2c9 tbody tr {
#   color: blue;
# }
# #T_3e2c9 tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T_3e2c9_row0_col34, #T_3e2c9_row0_col35, #T_3e2c9_row0_col36, #T_3e2c9_row0_col38, #T_3e2c9_row0_col39, #T_3e2c9_row0_col40, #T_3e2c9_row0_col41, #T_3e2c9_row0_col43, #T_3e2c9_row0_col44, #T_3e2c9_row0_col45, #T_3e2c9_row0_col46, #T_3e2c9_row0_col47, #T_3e2c9_row0_col48, #T_3e2c9_row0_col49, #T_3e2c9_row0_col50, #T_3e2c9_row1_col20, #T_3e2c9_row1_col21, #T_3e2c9_row1_col23, #T_3e2c9_row1_col24, #T_3e2c9_row1_col25, #T_3e2c9_row1_col26, #T_3e2c9_row1_col27, #T_3e2c9_row1_col28, #T_3e2c9_row1_col29, #T_3e2c9_row1_col30, #T_3e2c9_row1_col31, #T_3e2c9_row1_col33, #T_3e2c9_row1_col34, #T_3e2c9_row1_col35, #T_3e2c9_row1_col36, #T_3e2c9_row1_col37, #T_3e2c9_row1_col38, #T_3e2c9_row1_col39, #T_3e2c9_row1_col40, #T_3e2c9_row1_col41, #T_3e2c9_row1_col43, #T_3e2c9_row1_col44, #T_3e2c9_row1_col45, #T_3e2c9_row1_col46, #T_3e2c9_row1_col48, #T_3e2c9_row1_col49, #T_3e2c9_row1_col50, #T_3e2c9
, #T_3e2c9_row4_col23, #T_3e2c9_row4_col24, #T_3e2c9_row4_col25, #T_3e2c9_row4_col26, #T_3e2c9_row4_col27, #T_3e2c9_row4_col28, #T_3e2c9_row4_col29, #T_3e2c9_row4_col30, #T_3e2c9_row4_col31, #T_3e2c9_row4_col32, #T_3e2c9_row4_col33, #T_3e2c9_row4_col34, #T_3e2c9_row4_col35, #T_3e2c9_row4_col36, #T_3e2c9_row4_col37, #T_3e2c9_row4_col38, #T_3e2c9_row4_col39, #T_3e2c9_row4_col40, #T_3e2c9_row4_col41, #T_3e2c9_row4_col42, #T_3e2c9_row4_col43, #T_3e2c9_row4_col44, #T_3e2c9_row4_col45, #T_3e2c9_row4_col46, #T_3e2c9_row4_col47, #T_3e2c9_row4_col48, #T_3e2c9_row4_col49, #T_3e2c9_row4_col50, #T_3e2c9_row4_col51, #T_3e2c9_row4_col52, #T_3e2c9_row4_col53, #T_3e2c9_row4_col54, #T_3e2c9_row4_col55, #T_3e2c9_row4_col56, #T_3e2c9_row5_col0, #T_3e2c9_row5_col1, #T_3e2c9_row5_col2, #T_3e2c9_row5_col3, #T_3e2c9_row5_col4, #T_3e2c9_row5_col5, #T_3e2c9_row5_col6, #T_3e2c9_row5_col7, #T_3e2c9_row5_col8, #T_3e2c9_row5_col9, #T_3e2c9_row5_col10, #T_3e2c9_row5_col11, #T_3e2c9_row5_col12, #T_3e2c9_row5_col13 ...
#   background-color: lightgreen;
#   color: white;
# }
# </style>
# <table id="T_3e2c9" class="dataframe">
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\1418307944.py:90: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Returns (Open to Close, Month-Letter-WeekOfMonth)</h3>
# <style type="text/css">
# #T_96dde thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_96dde tbody td {
#   text-align: center;
#   color: black;
# }
# #T_96dde tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_96dde tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_96dde table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_96dde th {
#   padding: 8px;
# }
# #T_96dde td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_96dde tbody tr {
#   color: blue;
# }
# #T_96dde tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T_96dde_row0_col34, #T_96dde_row0_col36, #T_96dde_row0_col38, #T_96dde_row0_col39, #T_96dde_row0_col45, #T_96dde_row0_col47, #T_96dde_row1_col20, #T_96dde_row1_col24, #T_96dde_row1_col25, #T_96dde_row1_col26, #T_96dde_row1_col29, #T_96dde_row1_col35, #T_96dde_row1_col37, #T_96dde_row1_col40, #T_96dde_row1_col41, #T_96dde_row1_col46, #T_96dde_row1_col49, #T_96dde_row1_col53, #T_96dde_row2_col1, #T_96dde_row2_col3, #T_96dde_row2_col7, #T_96dde_row2_col10, #T_96dde_row2_col11, #T_96dde_row2_col19, #T_96dde_row2_col20, #T_96dde_row2_col23, #T_96dde_row2_col24, #T_96dde_row2_col25, #T_96dde_row2_col28, #T_96dde_row2_col29, #T_96dde_row2_col35, #T_96dde_row2_col36, #T_96dde_row2_col38, #T_96dde_row2_col39, #T_96dde_row2_col40, #T_96dde_row3_col17, #T_96dde_row3_col18, #T_96dde_row3_col21, #T_96dde_row3_col23, #T_96dde_row3_col24, #T_96dde_row3_col25, #T_96dde_row3_col28, #T_96dde_row3_col31, #T_96dde_row3_col32, #T_96dde
col53, #T_96dde_row5_col54, #T_96dde_row5_col55, #T_96dde_row5_col56, #T_96dde_row6_col0, #T_96dde_row6_col2, #T_96dde_row6_col4, #T_96dde_row6_col5, #T_96dde_row6_col6, #T_96dde_row6_col8, #T_96dde_row6_col9, #T_96dde_row6_col12, #T_96dde_row6_col13, #T_96dde_row6_col14, #T_96dde_row6_col15, #T_96dde_row6_col16, #T_96dde_row6_col18, #T_96dde_row6_col19, #T_96dde_row6_col20, #T_96dde_row6_col21, #T_96dde_row6_col22, #T_96dde_row6_col23, #T_96dde_row6_col26, #T_96dde_row6_col27, #T_96dde_row6_col28, #T_96dde_row6_col29, #T_96dde_row6_col30, #T_96dde_row6_col31, #T_96dde_row6_col33, #T_96dde_row6_col34, #T_96dde_row6_col35, #T_96dde_row6_col36, #T_96dde_row6_col37, #T_96dde_row6_col38, #T_96dde_row6_col39, #T_96dde_row6_col40, #T_96dde_row6_col41, #T_96dde_row6_col43, #T_96dde_row6_col44, #T_96dde_row6_col45, #T_96dde_row6_col46, #T_96dde_row6_col48, #T_96dde_row6_col49, #T_96dde_row6_col50, #T_96dde_row6_col51, #T_96dde_row6_col52, #T_96dde_row6_col53, #T_96dde_row6_col54, #T_96dde_row6_col55, #T_96dde_row6_col56, #T_96dde_row7_col0, #T_96dde_row7_col2, #T_96dde_row7_col4, #T_96dde_row7_col5, #T_96dde_row7_col6, #T_96dde_row7_col8, #T ...
#   background-color: lightgreen;
#   color: white;
# }
# </

# %%
import ccxt
import pandas as pd
from IPython.display import display, HTML
from datetime import timedelta

# Function to fetch ETH/USDT historical data from Binance
def fetch_data(symbol, timeframe='1w', since='2000-01-01T00:00:00Z'):
    exchange = ccxt.binance()
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=exchange.parse8601(since))

    # Convert to DataFrame
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    # Extract year, month, and week for pivot table analysis
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['week_of_year'] = df.index.isocalendar().week  # Get the week number of the year
    df['week_of_month'] = (df.index.day - 1) // 7 + 1  # Calculate which week of the month
    df['month_week'] = 'M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)

    # Generate a unique "week number" for sorting (unique within the same year)
    df['month_letter'] = df['month'].apply(lambda x: chr(64 + x))  # Convert month to letter (1 -> A, 2 -> B, ..., 12 -> L)
    # Create unique "week number" format: MonthLetter-MonthNumber-WeekOfMonth
    df['unique_week_number'] = df['month_letter'] + '-M' + df['month'].astype(str) + '-W' + df['week_of_month'].astype(str)
    
    return df

# Function to filter data for the 18 months after each halving event
def filter_halving_data(df):
    halving_dates = ['2012-11-28', '2016-07-10', '2020-05-12', '2024-04-20']
    halving_dates = pd.to_datetime(halving_dates)

    # Filter the DataFrame to only include data from 18 months after each halving date
    filtered_df = pd.DataFrame()
    for halving_date in halving_dates:
        start_date = halving_date
        end_date = start_date + timedelta(weeks=18*4)  # 18 months = 18 * 4 weeks
        filtered_df = pd.concat([filtered_df, df[(df.index >= start_date) & (df.index <= end_date)]])

    return filtered_df

# Function to calculate max drawdown (from open to low)
def calculate_max_drawdown(df):
    df['max_drawdown'] = (df['low'] - df['open']) / df['open'] * 100
    return df

# Function to calculate open-to-high percentage change
def calculate_high_to_open_change(df):
    df['high_to_open_change'] = (df['high'] - df['open']) / df['open'] * 100
    return df

# Function to calculate weekly return (from open to close)
def calculate_weekly_return(df):
    df['weekly_return'] = (df['close'] - df['open']) / df['open'] * 100
    return df

# Function to add the halving week number and halving count columns
def add_halving_columns(df):
    halving_dates = pd.to_datetime(['2012-11-28', '2016-07-10', '2020-05-12', '2024-04-20'])
    halving_counts = [1, 2, 3, 4]
    
    # Create new columns to store the week after halving and halving count
    df['week_after_halving'] = None
    df['halving_count'] = None

    # Iterate over each halving event
    for i, halving_date in enumerate(halving_dates):
        # Calculate the weeks since each halving event
        df.loc[df.index >= halving_date, 'week_after_halving'] = ((df.index[df.index >= halving_date] - halving_date).days // 7) + 1
        df.loc[df.index >= halving_date, 'halving_count'] = halving_counts[i]
    
    return df

# Function to create and style the pivot table with positive percentages in green
def create_pivot_table(df, value_column):
    # Sort by the unique_week_number column to ensure correct order
    df = df.sort_values('week_after_halving')
    
    # Create the pivot table
    pivot_table = df.pivot_table(values=value_column, index='halving_count', columns='week_after_halving', aggfunc='mean')

    # Calculate mean, median, max, and min for each column
    avg_value = pivot_table.mean(axis=0)
    median_value = pivot_table.median(axis=0)
    max_value = pivot_table.max(axis=0)
    min_value = pivot_table.min(axis=0)

    # Add the average, median, max, and min as the last rows
    pivot_table.loc['Avg'] = avg_value
    pivot_table.loc['Median'] = median_value
    pivot_table.loc['Max'] = max_value
    pivot_table.loc['Min'] = min_value

    # Function to color positive values green and negative values red
    def color_positive_negative(val):
        if isinstance(val, (int, float)):
            if val > 0:
                return 'background-color: lightgreen; color: white;'  # Green for positive values
            elif val < 0:
                return 'background-color: pink; color: white;'  # Red for negative values
        return ''  # No change for non-numeric values

    # Style the table
    styled_table = pivot_table.style \
        .format('{:.2f}%') \
        .applymap(color_positive_negative)  # Apply the coloring function to the table
    
    # Set additional styles
    styled_table.set_table_styles([ 
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'), ('color', 'black')]},
        {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#f2f2f2')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ffffff')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%'), ('display', 'block'), ('overflow-x', 'auto'), ('position', 'relative')]},  # Set relative position for the table container
        {'selector': 'th', 'props': [('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px'), ('border', '1px solid #ddd')]},
        {'selector': 'tbody tr', 'props': [('color', 'blue')]},
        
        # Add a line below the "Avg" row to separate it from the rest of the table
        {'selector': 'tr:nth-last-child(5)', 'props': [('border-bottom', '2px solid black')]},  # Row for "Avg"
    ]) \
    .set_table_attributes('class="dataframe"')

    return styled_table

# Function to display the table with a title
def display_table(title, styled_table):
    display(HTML(f"<h3>{title}</h3>"))
    display(styled_table)

# Main function to fetch data, process it, and display the results
def main():
    # Fetch data
    symbol = 'ETH/USDT'
    ETH_data = fetch_data(symbol)

    # Filter data for 18 months after each halving
    ETH_data = filter_halving_data(ETH_data)

    # Add halving week and halving count columns
    ETH_data = add_halving_columns(ETH_data)

    # Calculate indicators
    ETH_data = calculate_max_drawdown(ETH_data)
    ETH_data = calculate_high_to_open_change(ETH_data)
    ETH_data = calculate_weekly_return(ETH_data)

    # Create and display the pivot tables
    styled_table_max_drawdown = create_pivot_table(ETH_data, 'max_drawdown')
    display_table("ETH/USDT Weekly Max Drawdown (Week After Halving)", styled_table_max_drawdown)

    styled_table_high_to_open_change = create_pivot_table(ETH_data, 'high_to_open_change')
    display_table("ETH/USDT Weekly Open to High % Change (Week After Halving)", styled_table_high_to_open_change)

    styled_table_weekly_return = create_pivot_table(ETH_data, 'weekly_return')
    display_table("ETH/USDT Weekly Returns (Open to Close, Week After Halving)", styled_table_weekly_return)

# Run the main function
main()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_26000\612253741.py:108: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_positive_negative)  # Apply the coloring function to the table
# <h3>ETH/USDT Weekly Max Drawdown (Week After Halving)</h3>
# <style type="text/css">
# #T_b9655 thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_b9655 tbody td {
#   text-align: center;
#   color: black;
# }
# #T_b9655 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_b9655 tbody tr:nth-child(even) {
#   background-color: #ffffff;
# }
# #T_b9655 table {
#   border-collapse: collapse;
#   width: 100%;
#   display: block;
#   overflow-x: auto;
#   position: relative;
# }
# #T_b9655 th {
#   padding: 8px;
# }
# #T_b9655 td {
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_b9655 tbody tr {
#   color: blue;
# }
# #T_b9655 tr:nth-last-child(5) {
#   border-bottom: 2px solid black;
# }
# #T_b9655_row0_col57, #T_b9655_row0_col58, #T_b9655_row0_col59, #T_b9655_row0_col60, #T_b9655_row0_col61, #T_b9655_row0_col62, #T_b9655_row0_col63, #T_b9655_row0_col64, #T_b9655_row0_col65, #T_b9655_row0_col66, #T_b9655_row0_col67, #T_b9655_row0_col68, #T_b9655_row0_col69, #T_b9655_row0_col70, #T_b9655_row0_col71, #T_b9655_row1_col0, #T_b9655_row1_col1, #T_b9655_row1_col2, #T_b9655_row1_col3, #T_b9655_row1_col4, #T_b9655_row1_col5, #T_b9655_row1_col6, #T_b9655_row1_col7, #T_b9655_row1_col8, #T_b9655_row1_col9, #T_b9655_row1_col10, #T_b9655_row1_col11, #T_b9655_row1_col12, #T_b9655_row1_col13, #T_b9655_row1_col14, #T_b9655_row1_col15, #T_b9655_row1_col16, #T_b9655_row1_col17, #T_b9655_row1_col18, #T_b9655_row1_col19, #T_b9655_row1_col20, #T_b9655_row1_col21, #T_b9655_row1_col22, #T_b9655_row1_col23, #T_b9655_row1_col24, #T_b9655_row1_col25, #T_b9655_row1_col26, #T_b9655_row1_col27, #T_b9655_row1_col28, #T_b9655_row1_col29, #T_b9655_row1_col30, #T_b9655_row1_col31, #T_b9655_row1_col32, #T_b9655_row1_col33, #T_b9655_row1_col34, #T_b9655_row1_col35, #T_b9655_row1_col36, #T_b9655_row1_col37, #T_b9655_row1_col38, #T_b9655_row1_col39, #T_b9655_row1_col40, #T_b9655_row1_col41, #T_b9655_row1_col42, #T_b9655_row1_col43, #T_b9655_row1_col44, #T_b9655_row1_col45, #T_b9655_row1_col46, #T_b9655_row1_col47, #T_b9655_row1_col48, #T_b9655_row1_col49, #T_b9655_row1_col50, #T_b9655_row1_col51, #T_b9655_row1_col52, #T_b9655_row1_col53, #T_b9655_row1_col54, #T_b9655_row1_col55, #T_b9655_row1_col56, #T_b9655_row1_col57, #T_b9655_row1_col58, #T_b9655_row1_col59, #T_b9655_row1_col60, #T_b9655_row1_col61, #T_b9655_row1_col62, #T_b9